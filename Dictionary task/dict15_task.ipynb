# %%
d15 = {
    "Name": "Saloni",
    "occupation": "Student",
    "Class": "MCA 1st_year",
    "Age": 21,
    "Dream": "Officer",
}

print(d15)
# Out:
# {'Name': 'Saloni', 'occupation': 'Student', 'Class': 'MCA 1st_year', 'Age': 21, 'Dream': 'Officer'}

# %%
d15["Dream"] = "Data_Analytics"

print(d15)
# Out:
# {'Name': 'Saloni', 'occupation': 'Student', 'Class': 'MCA 1st_year', 'Age': 21, 'Dream': 'Data_Analytics'}

# %%
d15 = ["Student","Data_Analytics"]
d15.append("nurse")

print(d15)
# Out:
# ['Student', 'Data_Analytics', 'nurse']
