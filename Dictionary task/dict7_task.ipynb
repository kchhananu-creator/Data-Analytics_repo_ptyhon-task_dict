# %%
d7 = {
    "college_name": "kdk College",
    "city": "Nagpur",
    "course": "MCA",
    "year": 2025,
    "subject": "ds"
}

print(d7)
# Out:
# {'college_name': 'kdk College', 'city': 'Nagpur', 'course': 'MCA', 'year': 2025, 'subject': 'ds'}

# %%
d7 = ["MCA", "MBA",]             

d7.extend(["M.COM", "MSW"])  

print(d7)
# Out:
# ['MCA', 'MBA', 'M.COM', 'MSW']
