# %%
d13 = {
    "bank_name": "SBI",
    "bank_ifsc": "SBIN00000000",
    "bank_branch": "Sitabuldi",
    "bank_city": "Nagpur",
    "bank_type": "Govt"
}
print(d13)

# %%
d13 = ["Nagpur"]    

d13.append("Amaravti")
