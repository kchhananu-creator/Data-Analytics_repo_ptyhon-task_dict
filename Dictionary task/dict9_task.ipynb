# %%
d9 = {
    "id":101,
    "name":"john",
    "marks":[60,70,80],
    "city":"pune",
    "status":True
}
print(d9)
# Out:
# {'id': 101, 'name': 'john', 'marks': [60, 70, 80], 'city': 'pune', 'status': True}

# %%
print(d9["status"])
# Out:
# True

# %%
d9["city"] = "pune2"

print(d9)
# Out:
# {'id': 101, 'name': 'john', 'marks': [60, 70, 80], 'city': 'pune2', 'status': True}

# %%
d9.clear()

print(d9)
# Out:
# {}
