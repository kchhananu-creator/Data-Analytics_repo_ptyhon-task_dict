# %%
d3 = {
    "Account_holder": "Karina",
    "Account_no": 70067676767,
    "Account_type": "Saving",
    "Brach": "Nadanvan",
    "Bank_type": "SBI"
}

print(d3)

# %%
d3.insert("Karina","Neha")

print(d3)
