# %%
d12 = {
    "Hostel_Name": "VENCUTESHVER_HOSTEL",
    "Total_girls": 100,
    "Worden": 1,
    "President": 2,
    "Guard": 3
}

print(d12)
# Out:
# {'Hostel_Name': 'VENCUTESHVER_HOSTEL', 'Total_girls': 100, 'Worden': 1, 'President': 2, 'Guard': 3}

# %%
d12.clear()

print(d12)
# Out:
# {}
