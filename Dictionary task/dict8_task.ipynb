# %%
d8 = {
    "order_id": 9001,
    "order_item": "Keyboard",
    "order_qty": 2,
    "order_price": 1200.50,
    "order_status": True
}
print(d8)
# Out:
# {'order_id': 9001, 'order_item': 'Keyboard', 'order_qty': 2, 'order_price': 1200.5, 'order_status': True}

# %%
d8.update({"order_bujet":1000})
print(d8)
# Out:
# {'order_id': 9001, 'order_item': 'Keyboard', 'order_qty': 2, 'order_price': 1200.5, 'order_status': True, 'order_bujet': 1000}
