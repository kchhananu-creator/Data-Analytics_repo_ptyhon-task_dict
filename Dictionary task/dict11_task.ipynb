# %%
d11 = {
    "a": "1_ball",
    "b": "2_Apple",
    "c": "3_banana",
    "d": "4_mango",
    "e":  "5_bat"
    }

print(d11)
# Out:
# {'a': '1_ball', 'b': '2_Apple', 'c': '3_banana', 'd': '4_mango', 'e': '5_bat'}

# %%
d11.update({"f":"6null"})

print(d11)
# Out:
# {'f': '6null'}

# %%
d11.clear()

print(d11)
# Out:
# {}
