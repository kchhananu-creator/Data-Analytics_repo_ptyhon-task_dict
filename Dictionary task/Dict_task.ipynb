# %%
d1 = {
    "name": "Asha",
    "age": 21,
    "city": "Nagpur",
    "course": "MA",
    "marks": 85
}

print(d1)
# Out:
# {'name': 'Asha', 'age': 21, 'city': 'Nagpur', 'course': 'MA', 'marks': 85}

# %%
print(d1["age"])
# Out:
# 21

# %%
d1.update({"course": "cs"})
print(d1)
# Out:
# {'name': 'Asha', 'age': 21, 'city': 'Nagpur', 'course': 'cs', 'marks': 85}

# %%
d1.pop("city")
# Out:
# 'Nagpur'
