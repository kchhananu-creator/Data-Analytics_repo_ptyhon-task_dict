# %%
d6 = {
    "mob_brand":"Samsung",
    "mob_model":"A50",
    "mob_ram":"6GB",
    "mob_storage":"128GB",
    "mob_price":18000
}
print(d6)
# Out:
# {'mob_brand': 'Samsung', 'mob_model': 'A50', 'mob_ram': '6GB', 'mob_storage': '128GB', 'mob_price': 18000}

# %%
print(d6.clear())
# Out:
# None
