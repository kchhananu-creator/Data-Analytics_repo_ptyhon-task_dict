# %%
d14 = {
    "hos_name": "CityCare",
    "hos_doctor": "Dr.Sharma",
    "hos_beds": 50,
    "hos_city": "Nagpur",
    "hos_type": "Private"
}
print(hospital.get("hos_name"))
# Out:
# CityCare

# %%
d14 = d14.copy()
print(d14)
# Out:
# {'hos_name': 'CityCare', 'hos_doctor': 'Dr.Sharma', 'hos_beds': 50, 'hos_city': 'Nagpur', 'hos_type': 'Private'}

# %%
d14.clear()
print(d14)
# Out:
# {}
