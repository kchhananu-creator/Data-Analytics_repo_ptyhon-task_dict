# %%
d4 = {
    "book_id": 11,
    "book_title": "Python",
    "book_author": "ABC",
    "book_price": 350,
    "book_pages": 200
}
print(d4)
# Out:
# {'book_id': 11, 'book_title': 'Python', 'book_author': 'ABC', 'book_price': 350, 'book_pages': 200}

# %%
d4_copy = d4.copy()
print(d4_copy)
# Out:
# {'book_id': 11, 'book_title': 'Python', 'book_author': 'ABC', 'book_price': 350}
