# %%
d2 = {
     "student": "Girl",
        "name": "Ragini",
        "marks": [70, 80, 90],
        "address": "Pune",
        "age": 21
}
print(d2)
# Out:
# {'student': 'Girl', 'name': 'Ragini', 'marks': [70, 80, 90], 'address': 'Pune', 'age': 21}

# %%
d2 = ["Ragini", "Sonal", "Divya"]
d2.extend(["Divya","purvi"])

print(d2)
# Out:
# ['Ragini', 'Sonal', 'Divya', 'Divya', 'purvi']

# %%
d2.clear()

print(d2)
# Out:
# {}
